# %% [markdown]
# <a href="https://colab.research.google.com/github/anhquoccoi/homework/blob/main/nhandiencamxuc03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from sklearn.preprocessing import StandardScaler
from keras.utils import np_utils
from sklearn.utils import shuffle
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pickle
import tensorflow as tf
import math as m
from tensorflow.keras.optimizers import Adam, RMSprop,SGD
import pandas as pd
from tensorflow.keras.utils import to_categorical

with open('Nhandiencamxuc.pickle', 'rb') as f:
  (x_train, y_train), (x_test, y_test) = pickle.load(f)
x_1 = x_train
x_2 = x_test
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
y_train = to_categorical(y_train,4)
y_test = to_categorical(y_test,4)
y_train.shape
# Out:
# (80, 4)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape = (150,150,3,)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(64,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(4,activation='softmax'))
model.summary()
opt='adam'
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train,y_train, epochs=50, verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 150, 150, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 75, 75, 32)        9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 37, 37, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 18, 18, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 18, 18, 128)       73856
#
#  max_pooling2d_15 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 10368)             0
#
#  dense_15 (Dense)            (None, 128)               1327232
#
#  dense_16 (Dense)            (None, 128)               16512
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dense_18 (Dense)            (None, 64)                4160
#
#  dense_19 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 1,458,916
# Trainable params: 1,458,916
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 1s 23ms/step - loss: 3.8735 - accuracy: 0.1625
# Epoch 2/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.7307 - accuracy: 0.2250
# Epoch 3/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4306 - accuracy: 0.2875
# Epoch 4/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3230 - accuracy: 0.3250
# Epoch 5/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2465 - accuracy: 0.5375
# Epoch 6/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1848 - accuracy: 0.5750
# Epoch 7/50
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1199 - accuracy: 0.6000
# Epoch 8/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9587 - accuracy: 0.7500
# Epoch 9/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8195 - accuracy: 0.7625
# Epoch 10/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7329 - accuracy: 0.7500
# Epoch 11/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6039 - accuracy: 0.7625
# Epoch 12/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4749 - accuracy: 0.8375
# Epoch 13/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4304 - accuracy: 0.8750
# Epoch 14/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3347 - accuracy: 0.8625
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1995 - accuracy: 0.9625
# Epoch 16/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1427 - accuracy: 0.9750
# Epoch 17/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0807 - accuracy: 0.9875
# Epoch 18/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0279 - accuracy: 0.9875
# Epoch 20/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0218 - accuracy: 0.9875
# Epoch 21/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 22/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 0s 18ms/step - loss: 9.7317e-04 - accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 0s 18ms/step - loss: 7.1902e-04 - accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 0s 18ms/step - loss: 5.4215e-04 - accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 0s 18ms/step - loss: 3.9136e-04 - accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 0s 19ms/step - loss: 3.2588e-04 - accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.8238e-04 - accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6519e-04 - accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.3530e-04 - accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1541e-04 - accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9797e-04 - accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8022e-04 - accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7115e-04 - accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.5441e-04 - accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.4426e-04 - accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3407e-04 - accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2804e-04 - accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1700e-04 - accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1288e-04 - accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0510e-04 - accuracy: 1.0000

# %%
pd.DataFrame(history.history).plot(figsize = (8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %%
test = 20
plt.imshow(cv2.cvtColor(x_1[test], cv2.COLOR_BGR2RGB))
print(x_1[test].shape)
img = x_1[test].reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Dự đoán là Ngạc Nhiên', 'Dự đoán là Hạnh Phúc', 'Dự đoán là Giận dữ','Dự đoán là Sợ Hãi']
Label[pred[0]]
# Out:
# (150, 150, 3)
# [1]
# 'Dự đoán là Hạnh Phúc'

# %%
test = 19
plt.imshow(cv2.cvtColor(x_1[test], cv2.COLOR_BGR2RGB))
print(x_1[test].shape)
img = x_1[test].reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Dự đoán là Ngạc Nhiên', 'Dự đoán là Hạnh Phúc', 'Dự đoán là Giận dữ','Dự đoán là Sợ Hãi']
Label[pred[0]]
# Out:
# (150, 150, 3)
# [0]
# 'Dự đoán là Ngạc Nhiên'

# %%
test = 26
plt.imshow(cv2.cvtColor(x_1[test], cv2.COLOR_BGR2RGB))
print(x_1[test].shape)
img = x_1[test].reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Dự đoán là Ngạc Nhiên', 'Dự đoán là Hạnh Phúc', 'Dự đoán là Giận dữ','Dự đoán là Sợ Hãi']
Label[pred[0]]
# Out:
# (150, 150, 3)
# [1]
# 'Dự đoán là Hạnh Phúc'

# %%
test = 50
plt.imshow(cv2.cvtColor(x_1[test], cv2.COLOR_BGR2RGB))
print(x_1[test].shape)
img = x_1[test].reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Dự đoán là Ngạc Nhiên', 'Dự đoán là Hạnh Phúc', 'Dự đoán là Giận dữ','Dự đoán là Sợ Hãi']
Label[pred[0]]
# Out:
# (150, 150, 3)
# [2]
# 'Dự đoán là Giận dữ'

# %%
#https://drive.google.com/file/d/1AYUNcB8mYH7MFwjr6YxhAvGxdTB0fZ9w/view?usp=sharing
